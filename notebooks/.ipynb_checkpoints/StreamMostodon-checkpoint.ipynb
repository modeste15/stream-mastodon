# %%
from mastodon import Mastodon
from pyspark.sql import SparkSession
from kafka import KafkaProducer
import json
import time
import logging
import re
from datetime import datetime
import pytz

# 1. Configuration du système de logs
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# 2. Configuration de l'accès à l'API Mastodon
logging.info("Configuration de l'accès à l'API Mastodon...")
mastodon = Mastodon(
    access_token='m6d7yGLo1ScqQqfKehJz0YgzuIowJf2UsCK3fRvNBUY',  # Remplacez par votre jeton d'accès
    api_base_url='https://mastodon.social'  # L'URL de votre instance Mastodon
)

# 3. Créer une session Spark
logging.info("Création de la session Spark...")
spark = SparkSession.builder \
    .appName("MastodonToKafkaStream") \
    .getOrCreate()

# 4. Configuration du producteur Kafka
logging.info("Configuration du producteur Kafka...")
producer = KafkaProducer(
    bootstrap_servers='kafka:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# 5. Fonction pour récupérer les posts depuis l'API Mastodon et les transformer
def fetch_mastodon_posts():
    logging.info("Récupération des posts depuis Mastodon...")
    # Récupérer les toots en temps réel (ici on récupère les 100 derniers toots)
    toots = mastodon.timeline_public(limit=100)

    for toot in toots:
        # Extraire les hashtags (tags) du toot
        tags = [tag['name'] for tag in toot['tags']]  # Récupère les noms des hashtags

        # Extraire les informations du toot
        toot_data = {
            'id': toot['id'],
            'username': toot['account']['username'],
            'display_name': toot['account']['display_name'],
            'content': toot['content'],
            'favourites_count': toot['favourites_count'],
            'reblogs_count': toot['reblogs_count'],
            'replies_count': toot['replies_count'],
            'tags': tags  # Ajout des hashtags ici
        }

        # Envoyer les données à Kafka
        producer.send('Mostodon_topic_stream', toot_data)

    #logging.info(f"{len(toots)} toots envoyés à Kafka.")

# 6. Stream en continu depuis Mastodon vers Kafka
def stream_mastodon_to_kafka():
    logging.info("Démarrage du stream Mastodon vers Kafka...")
    while True:
        try:
            fetch_mastodon_posts()
            logging.info("Attente de 5 secondes avant la prochaine récupération...")
            time.sleep(5)  # Attendre 5 secondes avant de récupérer les nouveaux posts
        except Exception as e:
            logging.error(f"Erreur lors du stream des données : {e}")

# 7. Lancer le stream
stream_mastodon_to_kafka()

# 8. Fermer le producteur Kafka à la fin (nécessaire si vous arrêtez le programme)
producer.close()
logging.info("Producteur Kafka fermé.")
# Out:
# 2024-10-16 12:15:55,595 - INFO - Configuration de l'accès à l'API Mastodon...
# 2024-10-16 12:15:55,752 - INFO - Création de la session Spark...
# 2024-10-16 12:16:00,032 - INFO - Configuration du producteur Kafka...
# 2024-10-16 12:16:00,072 - INFO - <BrokerConnection node_id=bootstrap-0 host=kafka:9092 <connecting> [IPv4 ('172.21.0.4', 9092)]>: connecting to kafka:9092 [('172.21.0.4', 9092) IPv4]
# 2024-10-16 12:16:00,074 - INFO - Probing node bootstrap-0 broker version
# 2024-10-16 12:16:00,076 - INFO - <BrokerConnection node_id=bootstrap-0 host=kafka:9092 <connecting> [IPv4 ('172.21.0.4', 9092)]>: Connection complete.
# 2024-10-16 12:16:00,186 - INFO - Broker version identified as 2.5.0
# 2024-10-16 12:16:00,187 - INFO - Set configuration api_version=(2, 5, 0) to skip auto check_version requests on startup
# 2024-10-16 12:16:00,197 - INFO - Démarrage du stream Mastodon vers Kafka...
# 2024-10-16 12:16:00,198 - INFO - Récupération des posts depuis Mastodon...
# 2024-10-16 12:16:00,932 - INFO - <BrokerConnection node_id=1 host=kafka:9092 <connecting> [IPv4 ('172.21.0.4', 9092)]>: connecting to kafka:9092 [('172.21.0.4', 9092) IPv4]
# 2024-10-16 12:16:00,934 - INFO - <BrokerConnection node_id=1 host=kafka:9092 <connecting> [IPv4 ('172.21.0.4', 9092)]>: Connection complete.
# 2024-10-16 12:16:00,934 - INFO - <BrokerConnection node_id=bootstrap-0 host=kafka:9092 <connected> [IPv4 ('172.21.0.4', 9092)]>: Closing connection.
# 2024-10-16 12:16:01,432 - INFO - Récupération des posts depuis Mastodon...
# 2024-10-16 12:16:02,351 - INFO - Récupération des posts depuis Mastodon...
# 2024-10-16 12:16:03,360 - INFO - Récupération des posts depuis Mastodon...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 73
#      70             logging.error(f"Erreur lors du stream des données : {e}")
#      72 # 7. Lancer le stream
# ---> 73 stream_mastodon_to_kafka()
#      75 # 8. Fermer le producteur Kafka à la fin (nécessaire si vous arrêtez le programme)
#      76 producer.close()
#
# Cell In [1], line 68, in stream_mastodon_to_kafka()
#      66     fetch_mastodon_posts()
#      67     #logging.info("Attente de 5 secondes avant la prochaine récupération...")
# ---> 68     time.sleep(0.5)  # Attendre 5 secondes avant de récupérer les nouveaux posts
#      69 except Exception as e:
#      70     logging.error(f"Erreur lors du stream des données : {e}")
#
# File /usr/local/spark/python/pyspark/context.py:363, in SparkContext._do_init.<locals>.signal_handler(signal, frame)
#     361 def signal_handler(signal: Any, frame: Any) -> NoReturn:
#     362     self.cancelAllJobs()
# --> 363     raise KeyboardInterrupt()
#
# KeyboardInterrupt:
