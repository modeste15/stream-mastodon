# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import max,col
import psycopg2
# 1. Créer une session Spark
spark = SparkSession.builder \
    .appName("PostgresToSpark") \
    .config("spark.jars", "/usr/local/spark/jars/postgresql-42.3.9.jar") \
    .getOrCreate()  # Assurez-vous que cette ligne ne se termine pas par un '\'

# 2. Configurer les paramètres de connexion
jdbc_url = "jdbc:postgresql://postgres:5432/DB_Mastodon"  # Remplacez 'postgres' et 'DB_Mastodon' par vos valeurs
properties = {
    "user": "fadi",        # Votre nom d'utilisateur PostgreSQL
    "password": "fadi",    # Votre mot de passe PostgreSQL
    "driver": "org.postgresql.Driver"  # Driver JDBC PostgreSQL
}

# 3. Lire les données depuis PostgreSQL
df = spark.read.jdbc(url=jdbc_url, table="toots", properties=properties)

df_cleaned = df.withColumn("content", regexp_replace(col("content"), "<[^>]+>", "")) #pour supprimer toutes les balises html 

df_max_values = df_cleaned.filter(
    (col("favourites_count") > 1) | 
    (col("reblogs_count") > 1) | 
    (col("replies_count") > 1)
)



# Afficher les résultats
df_max_values.show()

print("Connexion à PostgreSQL...")
conn = psycopg2.connect(
    host="postgres",  # Changez ceci si nécessaire
    database="DB_Mastodon",
    user="fadi",
    password="fadi"
)
cursor = conn.cursor()

# Création de la table si elle n'existe pas déjà
create_table_query = '''
CREATE TABLE IF NOT EXISTS Toots_SILVER (
    id BIGINT PRIMARY KEY,
    username TEXT NOT NULL,
    display_name TEXT NOT NULL,
    content TEXT NOT NULL,
    favourites_count INT NOT NULL,
    reblogs_count INT NOT NULL,
    replies_count INT NOT NULL
);
'''
cursor.execute(create_table_query)
conn.commit()


df_cleaned.write.jdbc(url=jdbc_url, table="Toots_SILVER", mode="overwrite", properties=properties)

# Compter le nombre total d'entrées dans la table 'toots'
    print("Calcul du nombre total d'entrées dans la table 'toots'...")
    cursor.execute("SELECT COUNT(*) FROM toots_SILVER;")
    count = cursor.fetchone()[0]  # Récupérer le résultat du COUNT
    print(f"Nombre total d'entrées dans la table 'toots_SILVER' : {count}")

# 7. Fermer la session Spark
spark.stop()
# Out:
# +------------------+--------------------+--------------------+-----------------------------------+----------------+-------------+-------------+
# |                id|            username|        display_name|                            content|favourites_count|reblogs_count|replies_count|
# +------------------+--------------------+--------------------+-----------------------------------+----------------+-------------+-------------+
# |113231250200986282|                ARTi|         志保屋 榮造| 都民の日だから、学校が軒並み休みだ|              63|            5|           22|
# |113220957648540456|            nanasina|              ななし|                       ペプシうまい|               0|            2|            0|
# |113231225617973533|          Lazykisama| Spookhrystmasn Time|               Comienza es spook...|              83|           25|           22|
# |113231225772804502|           anakinbot|anakin skywalker bot|                  Oops, I broke it!|              64|           34|           11|
# |113231233232363273|        lauraritchie|    Laura Ritchie 🌸|               I need to make mo...|              46|           44|           16|
# |113231245328060404|           remoquete|Fabrizio Ferri-Be...|               Important: You ne...|              38|           47|            4|
# |113231245964617962|            risahana|                    |                       少し眠ってた|              98|           13|           11|
# |113231250200610527|lyckosmarre.bsky....|ᴍᴀʀʟᴇɴᴇ ᴛʏᴄᴋᴏꜱᴅᴏᴛ...|               Jag önskar att Vä...|              22|           30|            0|
# |113231272060503505|         GoogleJapan|              あんぴ|    vrchatでライブとか開催してれ...|               7|           10|           16|
# |113231240568452175|             sno_man|      ⛄❄す　の　担❄⛄| 今日はひかるくんの入所日〜!!!い...|              46|           36|           14|
# |113231265867456743|           surimochi|            すりもち|東海道新幹線は開業60周年ですわよ...|               5|           21|            2|
# |113231232702840352|            misryoum|                    |               مصر اليوم | «بقلا...|              41|           25|           25|
# |113231232698609930|fr.sputniknews.af...|🦜 Sputnik Afriqu...|               Le Niger dénonce ...|              79|            9|            1|
# |113231232697532625|fr.sputniknews.af...|🦜 Sputnik Afriqu...|               Le dialogue entre...|              93|            5|            1|
# |113231232691813079|        BBC3MusicBot|BBC Radio 3 🎶 #N...|               🔊 #NowPlaying on...|              53|           47|            8|
# |113231232691174158|                poes|          poes :pla:|               salah satu hal ya...|              27|           31|            9|
# |113231232662656252|          gamerslive|        GamersLiveFR|               Starfield : une n...|               0|           37|            6|
# |113231232605642367|             kuratha|                    |               TENDER FOR PROVIS...|               8|           30|           14|
# |113231232812760524|              cobalt|              cobalt|               Here are photos o...|               8|           11|           12|
# |113231232812324801|          gamerslive|        GamersLiveFR|               FF9 Remake : une ...|               5|           15|            3|
# +------------------+--------------------+--------------------+-----------------------------------+----------------+-------------+-------------+
# only showing top 20 rows
#
# Connexion à PostgreSQL...
